# %%
import numpy as np
import tensorflow as tf
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150,150,3)),
    tf.keras.layers.MaxPool2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPool2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPool2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPool2D(2,2),
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.5),
    # 512 neuron hiden layer
    tf.keras.layers.Dense(512,activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')
])

# %%
model.load_weights('secondmodel.h5')

# %%
def evaluate_play(user,computer):
    if user == '1':
        if computer == 2:
            return 'computer'
        if computer == 3:
            return 'user'
        return 'tie'
    if user == '2':
        if computer == 3:
            return 'computer'
        if computer == 1:
            return 'user'
        return 'tie'
    if user == '3':
        if computer == 1:
            return 'computer'
        if computer == 2:
            return 'user'
        return 'tie'

# %%
images = []
images.append(mpimg.imread('Data/rps-validation/rock1.png'))
images.append(mpimg.imread('Data/rps-validation/paper1.png'))
images.append(mpimg.imread('Data/rps-validation/scissors1.png'))

plt.figure(figsize=(20,10))
columns = 3
for i, image in enumerate(images):
    plt.subplot(len(images) / columns + 1, columns, i + 1)
    plt.imshow(image)

print('\t\t\t\tPick')
print()
print("\n       Rock(1)                Paper(2)             Scissors(3)")
# Out:
# 				Pick
#
#
#        Rock(1)                Paper(2)             Scissors(3)

# %%
user_pick = input()
# Out:
# 1

# %%
computer_pick = np.random.randint(1,4)
computer_pick
# Out:
# 3

# %%
print(f"{evaluate_play(user_pick,computer_pick)} wins" )
# Out:
# user wins
